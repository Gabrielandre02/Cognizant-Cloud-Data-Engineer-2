# %%
import pandas as pd
import pandera as pa

# %%
valore_ausentes = ['**', '###!', '####', '****', '*****', 'NULL']

df = pd.read_csv("https://raw.githubusercontent.com/ftiosso/dio-curso-etl/main/ocorrencia_2010_2020.csv",
                 sep=";", parse_dates=["ocorrencia_dia"], dayfirst=True, na_values=valore_ausentes)

# %%
#validaçao dos dados
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable=True),
        "ocorrencia_dia":pa.Column(pa.DateTime),
        "ocorrencia_hora":pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes":pa.Column(pa.Int)
    }
)

# %%
#validaçao 
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#verificar tipo dos dados
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
#bucas pelo index
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# ...

# %%
#buscar pelo label
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# ...

# %%
#duas formais de buscar coluna
df.ocorrencia_uf
#df.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
#mostrar valores nao informados( duas funçoes)
#df.isna().sum()
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
#buscar e uma coluna especifica (se tem valores ou nao.[falso diz que tem valor])
df.ocorrencia_uf.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5747    False
# 5748    False
# 5749    False
# 5750    False
# 5751    False
# Name: ocorrencia_uf, Length: 5752, dtype: bool

# %%
#localizar o dados que tem valor nulo na coluna
df.loc[df.ocorrencia_uf.isnull()]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0

# %%
#mostrar dados informados
df.count()
# Out:
# codigo_ocorrencia           5752
# codigo_ocorrencia2          5752
# ocorrencia_classificacao    5752
# ocorrencia_cidade           5752
# ocorrencia_uf               5751
# ocorrencia_aerodromo        3403
# ocorrencia_dia              5752
# ocorrencia_hora             5751
# total_recomendacoes         5752
# dtype: int64

# %%
#ocorrencias com mais de 10 recomendaçoes
filtro = df.total_recomendacoes > 10
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2795              52265               52265                 ACIDENTE
# 3930              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# ...

# %%
#ocorrencias com mais de 10 recomendaçoes , usando colunas especificas
filtro = df.total_recomendacoes > 10
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2795                SANTOS                   13
# 3930               VITÓRIA                   12

# %%
#ocorencia cuja a classificaçao seja 'algo selecionado'
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorencia cuja a classificaçao seja 'algo selecionado' E o estado e sp (e = &)
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5591              79540               79540          INCIDENTE GRAVE
# 5610              79566               79566          INCIDENTE GRAVE
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorencia cuja a classificaçao seja 'algo selecionado' ou o estado e sp (ou = |)
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorencia cuja a (classificaçao seja 'algo selecionado' ou 'algo selecionado') e o estado SP
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorencia cuja a (classificaçao seja 'algo selecionado' ou 'algo selecionado') e o estado SP (ISIN = OR)
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#TODAS AS CIDADES COMEÇA COM A LETRA C
fitro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#TODAS AS CIDADES TERMINAM  COM A LETRA A
filtro4 = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro4]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#TODAS AS CIDADES TERMINAM  COM A LETRA MA
filtro5 = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro5]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2655              51347               51347                INCIDENTE
# 2855              52340               52340                 ACIDENTE
# 2966              52832               52832                 ACIDENTE
# 2997              52979               52979                 ACIDENTE
# ...

# %%
#TODAS AS CIDADES CONTEM EM QUALQUER PARTE NA
filtro6 = df.ocorrencia_cidade.str.contains('MA')
df.loc[filtro6]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# 78                39916               39916          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5732              79745               79745                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5741              79754               79754          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#BUSCAR NA COLUNAS COM VALORES ESPECIFICOS
filtro6 = df.ocorrencia_cidade.str.contains('MA|AL')
df.loc[filtro6]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 17                39810               39810                INCIDENTE
# ...                 ...                 ...                      ...
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5741              79754               79754          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#OCORRENCIA DO ANO DE 2015
filtro7 = df.ocorrencia_dia.dt.year == 2015
df.loc[filtro7]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2996              52992               52992          INCIDENTE GRAVE
# 2997              52979               52979                 ACIDENTE
# 2998              53073               53073                INCIDENTE
# 2999              53074               53074                INCIDENTE
# 3000              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3462              60632               60632          INCIDENTE GRAVE
# 3463              60600               60600                INCIDENTE
# 3464              60642               60642                INCIDENTE
# 3465              60631               60631                 ACIDENTE
# 3466              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#OCORRENCIA DO ANO DE 2015 em mes 
filtro_ano = (df.ocorrencia_dia.dt.year == 2015)  
filtro_mes = (df.ocorrencia_dia.dt.month == 12)  
filtro_dia = (df.ocorrencia_dia.dt.day > 1)
filtro_final= (df.ocorrencia_dia.dt.day < 9)

df.loc[filtro_ano & filtro_mes & filtro_dia & filtro_final]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3430              53634               53634                INCIDENTE
# 3431              53636               53636                INCIDENTE
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3430                 PALMAS            TO                 SBPJ     2015-12-02
# ...

# %%
#CRIAR COLUNA DIA E HORA JUNTOS
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
#BUSCANDO POR DATA E HORA ESPECIFICA
filtro = df.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro1 = df.ocorrencia_dia_hora <= '2015-12-08 13:00:00'

df.loc[filtro & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3442              60611               60611                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#OCORRENCIA DO ANO DE 2015 E MES 3 e criando novo dataframe
filtro2 = df.ocorrencia_dia.dt.year == 2015
filtro3 = df.ocorrencia_dia.dt.month == 3
df2015 = df.loc[filtro2 & filtro3]

# %%
#mostrar quantidade de valores
df2015.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
#CONTANDO A QUANTIDADE PARA AGRUPAMENTO
df2015.groupby(['ocorrencia_classificacao']).ocorrencia_dia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: ocorrencia_dia, dtype: int64

# %%
#CONTANDO A QUANTIDADE PARA AGRUPAMENTO # contar para uma coluna que tem nulo pode causar problemas
df2015.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
#CONTA TODAS AS LINHAS ATE VALORES NULOS
df2015.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
#aagrupando e ordenando
df2015.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
#sudeste 
filtro2 = df.ocorrencia_dia.dt.year == 2010
filtro3 = df.ocorrencia_uf.isin(['SP','MG','ES','RJ'])
dfsudeste2010 = df.loc[filtro1 & filtro2]
dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 1                40349               40349                INCIDENTE
# 2                40351               40351                INCIDENTE
# 4                40324               40324                INCIDENTE
# 5                39807               39807                INCIDENTE
# ..                 ...                 ...                      ...
# 545              43551               43551                INCIDENTE
# 546              43754               43754                INCIDENTE
# 547              43806               43806                INCIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#         ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# INCIDENTE          362
# INCIDENTE GRAVE     61
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# INCIDENTE                 AC                6
#                           AL                1
#                           AM               15
#                           AP                1
#                           BA               23
#                           CE                4
#                           DF               20
#                           ES                5
#                           GO               12
#                           MA                7
#                           MG               39
#                           MS                2
#                           MT               12
#                           PA               15
#                           PB                3
#                           PE                7
#                           PI                1
#                           PR               28
#                           RJ               52
# ...

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO    42
# SÃO PAULO         26
# BRASÍLIA          22
# GUARULHOS         18
# SALVADOR          17
#                   ..
# ITAITUBA           1
# IMPERATRIZ         1
# ILHÉUS             1
# FORMOSA            1
# ÓBIDOS             1
# Length: 124, dtype: int64

# %%
filtro =  dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 3

# %%
#mostrar todos
dfsudeste2010.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAR     0
# SBAT     0
# SBBE     0
# SBBH     0
#         ..
# SWNS     1
# SWNV     1
# SWRD     0
# SWXV     1
# NaN     25
# Name: total_recomendacoes, Length: 84, dtype: int64

# %%
#mostrar somente com maiores que 0
filtro = dfsudeste2010.total_recomendacoes> 0 
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# ANÁPOLIS                1
# BRASÍLIA                9
# CAIRU                   4
# CAMAÇARI                5
# CANUTAMA                3
# CASCAVEL                2
# CURITIBA                4
# GOIÂNIA                 2
# ITAPETINGA              2
# LONDRINA                2
# MANAUS                  2
# NOVA XAVANTINA          1
# OLINDA                  8
# PALMAS                  1
# PONTA GROSSA            5
# PORTO ALEGRE            3
# PORTO UNIÃO             1
# RIO BRANCO              5
# RIO DE JANEIRO          3
# SALVADOR                5
# SANTO ÂNGELO            2
# SÃO JOSÉ DOS PINHAIS    1
# SÃO PAULO               2
# TIMÓTEO                 3
# VERA CRUZ               2
# VERANÓPOLIS             2
# Name: total_recomendacoes, dtype: int64

# %%
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade     ocorrencia_dia
# ANÁPOLIS              4                 1
# BRASÍLIA              2                 1
#                       5                 8
# CAIRU                 1                 4
# CAMAÇARI              5                 5
# CANUTAMA              1                 3
# CASCAVEL              1                 2
# CURITIBA              1                 2
#                       2                 2
# GOIÂNIA               4                 1
#                       12                1
# ITAPETINGA            5                 2
# LONDRINA              3                 2
# MANAUS                3                 2
# NOVA XAVANTINA        6                 1
# OLINDA                7                 8
# PALMAS                7                 1
# PONTA GROSSA          7                 5
# PORTO ALEGRE          8                 1
#                       9                 2
# PORTO UNIÃO           1                 1
# ...

# %%
filtro = dfsudeste2010.total_recomendacoes > 0 
filtro1 = dfsudeste2010.ocorrencia_cidade == 'SÃO PAULO'
dfsudeste2010.loc[filtro & filtro1]
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 219              41411               41411          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 219         SÃO PAULO            SP                 SBMT     2010-06-08
#
#     ocorrencia_hora  total_recomendacoes
# 219        19:30:00                    2
